# %% [markdown]
# # Weather Forecast LSTM
# ## Variabel: Tekanan Permukaan (PS)
# #### Pujo Prayogo 140810200038 <br>
#
# Best Hyperparameter: <br>
#     LSTM Layers   : 1<br>
#     Unit          : 128<br>
#     Activation    : tanh <br>
#     Learning Rate : 0.01<br>
#     MAE Score     : 0.00029029781580902636<br>
#
# R2 Score      : 0.9964505341173552 <br>
# MAPE Score    : 0.7169951050127463%

# %%
import pandas as pd
import numpy as np
import keras_tuner
import requests
import json
import matplotlib.pyplot as plt
import keras_tuner as kt
import model
import shutil
import os

from datetime import timedelta, datetime
from statsmodels.tsa.stattools import acf

from scikeras.wrappers import KerasRegressor
from scikeras.wrappers import KerasRegressor
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import r2_score, mean_squared_error
from sklearn.model_selection import train_test_split, GridSearchCV

from tensorflow.keras.activations import relu, tanh, sigmoid
from tensorflow.keras.optimizers import Adam, RMSprop
from tensorflow.keras.models import Sequential, load_model
from tensorflow.keras.layers import LSTM, Dense, Flatten, Input, Dropout
from tensorflow.keras.callbacks import EarlyStopping

# %% [markdown]
# # Import Data
#
# 1. Define fitur variabel, tanggal, dan koordinat lokasi
# 2. Import data cuaca melalui API POWER NASA
# 3. Konversi data JSON menjadi DataFrame

# %%
# ----- Parameter 
feature = "PS"  # Variabel: GWETROOT, WS10M, PS, PRECTOTCORR, RH2M, T2M

# ----- Data dan metric/satuannya
renamed_dict = {
    "GWETROOT": "Kelembaban Tanah",
    "WS10M": "Kecepatan Angin",
    "PS": "Tekanan Permukaan",
    "PRECTOTCORR": "Presipitasi",
    "RH2M": "Kelembaban Udara",
    "T2M": "Temperatur"
}

feature_name = renamed_dict[feature]  # Rename variabel fitur

metrics_dict = {
    "GWETROOT": "", #Hanya 0-1
    "WS10M": "m/s",
    "PS": "kPa",
    "PRECTOTCORR": "mm/day",
    "RH2M": "C",
    "T2M": "g/kg"
}

# ----- Tanggal dan Koordinat lokasi data pada POWER NASA
start_date = "20190101"
end_date = "20231231"
lat = "-6.3968"
long = "106.8458"

# ----- Download Data melalui API POWER NASA
request_url = (
    f"https://power.larc.nasa.gov/api/temporal/daily/point?"
    f"start={start_date}&end={end_date}&latitude={lat}&longitude={long}&community=ag&"
    f"parameters={feature}&format=json&user=pujo&header=true&time-standard=lst"
)
response = requests.get(url=request_url, verify=True, timeout=30.00)
content = json.loads(response.content.decode('utf-8'))

# ----- Konversi data ke DataFrame
df = pd.DataFrame.from_dict(content['properties']['parameter'])
df.index = pd.to_datetime(df.index, format='%Y%m%d')

# ----- Rename Kolom
df.rename(columns={feature: feature_name}, inplace=True)

# %% [markdown]
# #### Pengecekan data null/invalid (-999)

# %%
# ----- Cek Data
print(df, '\n\n')
print(df.info(), '\n')

# ----- Cek Data Invalid (Bernilai -999)
invalid_data = (df == -999).sum().sum()
print("TIDAK ADA DATA INVALID" if invalid_data == 0 else f"TERDAPAT DATA INVALID SEBANYAK {invalid_data} DATA")
# Out:
#             Tekanan Permukaan
# 2019-01-01              96.88
# 2019-01-02              96.90
# 2019-01-03              96.97
# 2019-01-04              96.96
# 2019-01-05              96.95
# ...                       ...
# 2023-12-27              97.05
# 2023-12-28              96.93
# 2023-12-29              96.83
# 2023-12-30              96.82
# 2023-12-31              96.83
#
# [1826 rows x 1 columns]
#
#
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1826 entries, 2019-01-01 to 2023-12-31
# Data columns (total 1 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Tekanan Permukaan  1826 non-null   float64
# dtypes: float64(1)
# memory usage: 28.5 KB
# None
#
# TIDAK ADA DATA INVALID

# %% [markdown]
# #### Visualisasi data dalam grafik
# Menampilkan grafik sebaran data

# %%
# ----- Visualisasi Data
plt.figure(figsize=(10, 4))
plt.plot(df.index, df[feature_name], label=feature_name)
plt.xlabel('Tahun')
plt.ylabel(metrics_dict[feature])  # Y-axis dinamis sesuai parameter
plt.title(f'Sebaran Data {feature_name}')
plt.grid(True)
plt.legend()
plt.show()

# %% [markdown]
# ## Autokorelasi
# Menampilkan grafik autokorelasi dengan acf untuk menentukan timesteps.
# Timesteps menurun secara konsisten sehingga diambil nilai acak sebagai timesteps, yaitu 30

# %%
# ----- Autokorelasi untuk menentukan TImesteps
def determine_timesteps(df, max_lag=60):
    lag_acf = acf(df[feature_name], nlags=max_lag)

    # Visualisasi autokorelasi
    plt.figure(figsize=(10, 4))
    plt.stem(range(len(lag_acf)), lag_acf)
    plt.title(f'Autocorrelation untuk {feature_name}')
    plt.xlabel('Lag (Hari)')
    plt.ylabel('Autocorrelation')
    plt.show()

    return lag_acf

autocorrelation = determine_timesteps(df)

# %% [markdown]
# ## Scaling data dengan MinMax
#
# 1. Scaling dengan MinMax
# 2. Pembagian data menjadi data Training (80%) dan data Testing (20%) tanpa mengubah urutan data
# 3. Visualisasi pembagian data training dan testing
#
# x' = x - min(x) / max(x) - min(x) <br>
# x = Data original

# %%
# ----- Scaling data dengan MinMax
scaler = MinMaxScaler()
scaled_data = scaler.fit_transform(df[[feature_name]])

# Train-Test Split (8:2)
X_train, X_test, y_train, y_test = train_test_split(
    scaled_data, scaled_data, test_size=0.2, shuffle=False
)

# ----- Visualisasi Train-Test Split
plt.figure(figsize=(10, 4))
plt.plot(df.index[:len(X_train)], X_train, label='Train')
plt.plot(df.index[len(X_train):], X_test, label='Test', color='orange')
plt.xlabel('Tahun')
plt.ylabel(metrics_dict[feature])
plt.title(f'Pembagian Data Train dan Test ({feature_name})')
plt.grid(True)
plt.legend()
plt.show()

# %% [markdown]
# ## Sequencing
#
# 1. Mendefinisikan timesteps
# 2. Membuat Fungsi untuk mempersiapkan data input yang sesuai format model LSTM.
#    Data diubah menjadi sekuens sepanjang timesteps (40)
# 4. Reshaping data menjadi format 3D untuk input LSTM [jumlah_sekuens, timesteps, jumlah_fitur]

# %%
timesteps = 40

# ----- Fungsi Membuat Sequence 
def create_sequences(X, time_steps):
    X_seq, y_seq = [], []
    for i in range(len(X) - time_steps):
        X_seq.append(X[i:i + time_steps])
        y_seq.append(X[i + time_steps])
    return np.array(X_seq), np.array(y_seq)

X_train_seq, y_train_seq = create_sequences(X_train, timesteps)
X_test_seq, y_test_seq = create_sequences(X_test, timesteps)

# ----- Reshape untuk LSTM
X_train_seq = X_train_seq.reshape((X_train_seq.shape[0], X_train_seq.shape[1], 1))
X_test_seq = X_test_seq.reshape((X_test_seq.shape[0], X_test_seq.shape[1], 1))

# %% [markdown]
# #### Membuat Directory untuk menyimpan hasil Tuning (Overwrite jika sudah ada)

# %%
#Hapus Directory Tuning (hanya untuk Tuning ulang)
#tuning_dir = f'lstm_tuning_{feature_name}_dir'

#if os.path.exists(tuning_dir):
#    shutil.rmtree(tuning_dir)
#    print(f"Deleted previous tuning directory: {tuning_dir}")
#else:
#    print(f"Tuning directory not found: {tuning_dir}")

# %% [markdown]
# # Hyperparameter Tuning dengan KerasTuner
# 1. Membuat fungsi model LSTM:
#    - Tuning jumlah layer LSTM (1 atau 2).
#     - Tuning jumlah unit per layer (32, 64, atau 128).
#     - Tuning fungsi aktivasi (relu, tanh, atau sigmoid).
#     - Tuning optimizer (adam atau rmsprop) dan learning rate (0.01 atau 0.001).
# 2. Menambah Dropout (0.2) untuk mencegah overfitting
# 3. Inisiasi Tuner dengan trials sebanyak 72 kombinasi dan 1 eksekusi/trial
# 4. Mengaplikasikan callback EarlyStopping untuk menghentikan pelatihan jika tidak terdapat perbaikan selama 15 epochs berturut-turut

# %%
# ----- Fungsi membangun Model LSTM dengan Keras Tuner
def build_model(hp):
    model = Sequential()

    # ------ Jumlah Layers, jumlah unit, fungsi aktivasi
    for i in range(hp.Choice('layers', [1, 2])):  # Tuning layer LSTM (2)
        model.add(LSTM(
            units=hp.Choice('filters', [32, 64, 128]),  # Tuning jumlah unit pada layer LSTM (3) 
            activation=hp.Choice('activation', ['relu', 'tanh', 'sigmoid']),  # Tuning fungsi aktivasi (3)
            return_sequences=True if i < hp.Choice('layers', [1, 2]) - 1 else False  
        ))
        model.add(Dropout(0.2)) # Dropout
    model.add(Dense(1))
    
    # ----- Optimizer dan Learning Rate
    optimizer_choice = hp.Choice('optimizer', ['adam', 'rmsprop']) # Tuning Optimizer (2)
    learning_rate = hp.Choice('learning_rate', [0.01, 0.001]) # Tuning learning Rate (2)
     
    if optimizer_choice == 'adam':
        optimizer = Adam(learning_rate=learning_rate)
    else:
        optimizer = RMSprop(learning_rate=learning_rate)
    
    # ----- Compile Model
    model.compile(optimizer=optimizer, loss='mean_squared_error', metrics=['mae'])
    
    return model

# --- Callback Early Stopping dengan Patience 15
early_stopping = EarlyStopping(
    monitor='val_loss',
    patience=15,
    restore_best_weights=True
)

# ----- Inisiasi Tuner 
tuner = kt.GridSearch(
    build_model,
    objective='val_loss',
    max_trials=72,  # Jumlah Kombinasi Hyperparameter
    executions_per_trial=1,  # 2x training per kombinasi hyperparameter
    directory=f'lstm_tuning_{feature_name}_dir',
    project_name=f'lstm_{feature_name}_tuning'
)
# Out:
# Reloading Tuner from lstm_tuning_Tekanan Permukaan_dir\lstm_Tekanan Permukaan_tuning\tuner0.json

# %% [markdown]
# #### Tuning dengan epochs 200 dan patience Earlystopping 15

# %%
# ----- Hyperparameter Tuning
tuner.search(
    X_train_seq, y_train_seq,
    epochs=200,
    batch_size=32,
    validation_data=(X_test_seq, y_test_seq),
    callbacks=[early_stopping]
)

# %% [markdown]
# #### Output Hyperparameter Tuning (Konfigurasi terbaik & hasil seluruh Trials)

# %%
# ----- Output Best Hyperparameter
best_hps = tuner.get_best_hyperparameters(num_trials=1)[0]
tuner_results = tuner.oracle.get_best_trials(num_trials=72)  
results = []

# Memasukkan Hasil Tuning ke DataFrame
for trial in tuner_results:
    values = trial.hyperparameters.values
    values['score'] = trial.score  # Nilai skor (mae)
    values['layers'] = trial.hyperparameters.get('layers')  # Menambahkan jumlah layer
    results.append(values)

df_results = pd.DataFrame(results)

# Tampilkan semua baris
pd.set_option('display.max_rows', None)  # Tampilkan semua baris
pd.set_option('display.max_columns', None)  # Tampilkan semua kolom

# Print Hyperparameter Terbaik
print("\n--- Setting Hyperparameter Terbaik ---")
print(f"Layer(s): {best_hps.get('layers')}")  # Menambahkan jumlah layer
print(f"Filters (units LSTM): {best_hps.get('filters')}")
print(f"Activation: {best_hps.get('activation')}")
print(f"Optimizer: {best_hps.get('optimizer')}")
print(f"Learning Rate: {best_hps.get('learning_rate')}")
print(f"Score (MAE): {best_hps.get('score')}\n\n")

# Print seluruh hasil hyperparameter tuning
print('Hasil Hyperparameter Tuning')
print(df_results)
# Out:
# --- Setting Hyperparameter Terbaik ---
# Layer(s): 2
# Filters (units LSTM): 128
# Activation: tanh
# Optimizer: rmsprop
# Learning Rate: 0.001
# Score (MAE): 0.00497373566031456
#
#
# Hasil Hyperparameter Tuning
#     layers  filters activation optimizer  learning_rate     score
# 0        2      128       tanh   rmsprop          0.001  0.004974
# 1        2       64       tanh   rmsprop          0.001  0.004982
# 2        1       64       tanh      adam          0.001  0.004987
# 3        1       64       tanh   rmsprop          0.001  0.004993
# 4        1      128       tanh      adam          0.001  0.004993
# 5        2       32       tanh   rmsprop          0.001  0.004997
# 6        1      128       tanh   rmsprop          0.001  0.005004
# 7        1       32       tanh      adam          0.010  0.005009
# 8        1       32       tanh   rmsprop          0.001  0.005030
# 9        1      128       tanh      adam          0.010  0.005031
# 10       1       32       tanh      adam          0.001  0.005061
# 11       2      128       tanh      adam          0.001  0.005065
# 12       1       64       tanh   rmsprop          0.010  0.005072
# 13       2       64       tanh   rmsprop          0.010  0.005078
# 14       2       32       tanh      adam          0.001  0.005085
# 15       2       32       tanh   rmsprop          0.010  0.005096
# 16       1      128       tanh   rmsprop          0.010  0.005097
# 17       1       64       tanh      adam          0.010  0.005105
# 18       2       64       tanh      adam          0.001  0.005116
# 19       2       32       tanh      adam          0.010  0.005121
# 20       1      128       relu      adam          0.010  0.005134
# 21       2       64       tanh      adam          0.010  0.005152
# 22       2      128       tanh      adam          0.010  0.005160
# 23       1       32       relu   rmsprop          0.010  0.005169
# 24       2      128       relu      adam          0.001  0.005176
# 25       1       64       relu   rmsprop          0.010  0.005188
# 26       1       32       relu      adam          0.001  0.005190
# 27       2       64    sigmoid      adam          0.010  0.005191
# 28       1       64    sigmoid      adam          0.010  0.005204
# 29       2      128    sigmoid   rmsprop          0.010  0.005212
# 30       1       64       relu      adam          0.010  0.005216
# 31       2      128    sigmoid      adam          0.010  0.005226
# 32       1      128       relu   rmsprop          0.001  0.005230
# 33       1       32       tanh   rmsprop          0.010  0.005241
# 34       2       32    sigmoid      adam          0.010  0.005251
# 35       1       64       relu   rmsprop          0.001  0.005260
# 36       1       32       relu      adam          0.010  0.005263
# 37       2       32       relu   rmsprop          0.010  0.005270
# 38       1       32    sigmoid      adam          0.010  0.005289
# 39       1       32       relu   rmsprop          0.001  0.005297
# 40       1       64       relu      adam          0.001  0.005307
# 41       2       64       relu      adam          0.001  0.005318
# 42       2      128       relu   rmsprop          0.010  0.005329
# 43       1      128       relu      adam          0.001  0.005357
# 44       2       64       relu      adam          0.010  0.005473
# 45       2       32       relu      adam          0.001  0.005483
# 46       2       64    sigmoid   rmsprop          0.010  0.005520
# 47       1      128       relu   rmsprop          0.010  0.005526
# 48       2      128       relu   rmsprop          0.001  0.005527
# 49       1      128    sigmoid      adam          0.001  0.005545
# 50       2       32    sigmoid   rmsprop          0.010  0.005577
# 51       2       32       relu   rmsprop          0.001  0.005648
# 52       2       64       relu   rmsprop          0.001  0.005690
# 53       1       32    sigmoid   rmsprop          0.010  0.005733
# 54       1      128    sigmoid      adam          0.010  0.005761
# 55       2       64       relu   rmsprop          0.010  0.005766
# 56       2       64    sigmoid      adam          0.001  0.005838
# 57       1       64    sigmoid   rmsprop          0.010  0.005850
# 58       1       64    sigmoid      adam          0.001  0.005943
# 59       1      128    sigmoid   rmsprop          0.010  0.006046
# 60       2       32       relu      adam          0.010  0.006046
# 61       1      128    sigmoid   rmsprop          0.001  0.006200
# 62       1       64    sigmoid   rmsprop          0.001  0.006502
# 63       2      128    sigmoid   rmsprop          0.001  0.006694
# 64       1       32    sigmoid      adam          0.001  0.007220
# 65       1       32    sigmoid   rmsprop          0.001  0.007661
# 66       2      128       relu      adam          0.010  0.015110
# 67       2       32    sigmoid   rmsprop          0.001  0.024237
# 68       2      128    sigmoid      adam          0.001  0.024819
# 69       2       64    sigmoid   rmsprop          0.001  0.025117
# 70       2      128       tanh   rmsprop          0.010  0.025936
# 71       2       32    sigmoid      adam          0.001  0.027272

# %% [markdown]
# ### Melatih ulang Model dengan Hyperparameter terbaik

# %%
# ----- Train Model dengan Hyperparameter terbaik
best_model = tuner.hypermodel.build(best_hps)

# --- LATIH ULANG MODEL DENGAN DATA TRAINING ---
history = best_model.fit(
    X_train_seq, y_train_seq,
    epochs=200,
    batch_size=32, 
    validation_data=(X_test_seq, y_test_seq),
    callbacks=[early_stopping]
)
# Out:
# Epoch 1/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 7s 60ms/step - loss: 0.0583 - mae: 0.1813 - val_loss: 0.0246 - val_mae: 0.1274
# Epoch 2/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 46ms/step - loss: 0.0214 - mae: 0.1187 - val_loss: 0.0142 - val_mae: 0.0958
# Epoch 3/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 43ms/step - loss: 0.0209 - mae: 0.1158 - val_loss: 0.0146 - val_mae: 0.0972
# Epoch 4/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 51ms/step - loss: 0.0156 - mae: 0.0991 - val_loss: 0.0135 - val_mae: 0.0940
# Epoch 5/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 49ms/step - loss: 0.0150 - mae: 0.0979 - val_loss: 0.0181 - val_mae: 0.1113
# Epoch 6/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 46ms/step - loss: 0.0152 - mae: 0.0983 - val_loss: 0.0111 - val_mae: 0.0847
# Epoch 7/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 52ms/step - loss: 0.0131 - mae: 0.0922 - val_loss: 0.0110 - val_mae: 0.0838
# Epoch 8/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 54ms/step - loss: 0.0131 - mae: 0.0929 - val_loss: 0.0104 - val_mae: 0.0826
# Epoch 9/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 52ms/step - loss: 0.0120 - mae: 0.0883 - val_loss: 0.0094 - val_mae: 0.0775
# Epoch 10/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 45ms/step - loss: 0.0108 - mae: 0.0829 - val_loss: 0.0091 - val_mae: 0.0766
# Epoch 11/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 46ms/step - loss: 0.0114 - mae: 0.0862 - val_loss: 0.0090 - val_mae: 0.0764
# Epoch 12/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 43ms/step - loss: 0.0118 - mae: 0.0877 - val_loss: 0.0092 - val_mae: 0.0774
# Epoch 13/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 47ms/step - loss: 0.0105 - mae: 0.0815 - val_loss: 0.0095 - val_mae: 0.0787
# Epoch 14/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 49ms/step - loss: 0.0103 - mae: 0.0799 - val_loss: 0.0086 - val_mae: 0.0742
# Epoch 15/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 50ms/step - loss: 0.0100 - mae: 0.0799 - val_loss: 0.0085 - val_mae: 0.0736
# Epoch 16/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 45ms/step - loss: 0.0104 - mae: 0.0800 - val_loss: 0.0117 - val_mae: 0.0887
# Epoch 17/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 43ms/step - loss: 0.0094 - mae: 0.0761 - val_loss: 0.0091 - val_mae: 0.0759
# Epoch 18/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 42ms/step - loss: 0.0096 - mae: 0.0778 - val_loss: 0.0095 - val_mae: 0.0774
# Epoch 19/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 41ms/step - loss: 0.0099 - mae: 0.0786 - val_loss: 0.0081 - val_mae: 0.0722
# Epoch 20/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 42ms/step - loss: 0.0090 - mae: 0.0756 - val_loss: 0.0108 - val_mae: 0.0853
# Epoch 21/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 43ms/step - loss: 0.0097 - mae: 0.0800 - val_loss: 0.0078 - val_mae: 0.0703
# Epoch 22/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 40ms/step - loss: 0.0092 - mae: 0.0772 - val_loss: 0.0098 - val_mae: 0.0806
# Epoch 23/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 42ms/step - loss: 0.0090 - mae: 0.0751 - val_loss: 0.0081 - val_mae: 0.0726
# Epoch 24/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 40ms/step - loss: 0.0087 - mae: 0.0739 - val_loss: 0.0099 - val_mae: 0.0813
# Epoch 25/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 45ms/step - loss: 0.0081 - mae: 0.0710 - val_loss: 0.0075 - val_mae: 0.0697
# Epoch 26/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 43ms/step - loss: 0.0081 - mae: 0.0713 - val_loss: 0.0068 - val_mae: 0.0655
# Epoch 27/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 42ms/step - loss: 0.0080 - mae: 0.0706 - val_loss: 0.0087 - val_mae: 0.0756
# Epoch 28/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 42ms/step - loss: 0.0081 - mae: 0.0710 - val_loss: 0.0065 - val_mae: 0.0643
# Epoch 29/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 51ms/step - loss: 0.0081 - mae: 0.0727 - val_loss: 0.0083 - val_mae: 0.0737
# Epoch 30/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 43ms/step - loss: 0.0078 - mae: 0.0706 - val_loss: 0.0081 - val_mae: 0.0729
# Epoch 31/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 43ms/step - loss: 0.0077 - mae: 0.0692 - val_loss: 0.0070 - val_mae: 0.0676
# Epoch 32/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 42ms/step - loss: 0.0075 - mae: 0.0682 - val_loss: 0.0063 - val_mae: 0.0639
# Epoch 33/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 45ms/step - loss: 0.0078 - mae: 0.0707 - val_loss: 0.0062 - val_mae: 0.0623
# Epoch 34/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 43ms/step - loss: 0.0078 - mae: 0.0709 - val_loss: 0.0061 - val_mae: 0.0618
# Epoch 35/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 48ms/step - loss: 0.0070 - mae: 0.0660 - val_loss: 0.0071 - val_mae: 0.0681
# Epoch 36/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 48ms/step - loss: 0.0069 - mae: 0.0670 - val_loss: 0.0061 - val_mae: 0.0624
# Epoch 37/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 45ms/step - loss: 0.0069 - mae: 0.0657 - val_loss: 0.0075 - val_mae: 0.0700
# Epoch 38/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 46ms/step - loss: 0.0070 - mae: 0.0660 - val_loss: 0.0059 - val_mae: 0.0619
# Epoch 39/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 46ms/step - loss: 0.0068 - mae: 0.0648 - val_loss: 0.0065 - val_mae: 0.0640
# Epoch 40/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 44ms/step - loss: 0.0067 - mae: 0.0656 - val_loss: 0.0056 - val_mae: 0.0598
# Epoch 41/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 46ms/step - loss: 0.0071 - mae: 0.0673 - val_loss: 0.0055 - val_mae: 0.0587
# Epoch 42/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 43ms/step - loss: 0.0069 - mae: 0.0654 - val_loss: 0.0068 - val_mae: 0.0668
# Epoch 43/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 44ms/step - loss: 0.0070 - mae: 0.0674 - val_loss: 0.0054 - val_mae: 0.0584
# Epoch 44/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 42ms/step - loss: 0.0068 - mae: 0.0655 - val_loss: 0.0055 - val_mae: 0.0599
# Epoch 45/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 40ms/step - loss: 0.0065 - mae: 0.0635 - val_loss: 0.0054 - val_mae: 0.0592
# Epoch 46/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 46ms/step - loss: 0.0065 - mae: 0.0635 - val_loss: 0.0058 - val_mae: 0.0618
# Epoch 47/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 41ms/step - loss: 0.0062 - mae: 0.0621 - val_loss: 0.0067 - val_mae: 0.0666
# Epoch 48/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 42ms/step - loss: 0.0060 - mae: 0.0619 - val_loss: 0.0063 - val_mae: 0.0641
# Epoch 49/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 45ms/step - loss: 0.0064 - mae: 0.0628 - val_loss: 0.0052 - val_mae: 0.0571
# Epoch 50/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 41ms/step - loss: 0.0067 - mae: 0.0643 - val_loss: 0.0059 - val_mae: 0.0620
# Epoch 51/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 46ms/step - loss: 0.0058 - mae: 0.0612 - val_loss: 0.0051 - val_mae: 0.0567
# Epoch 52/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 42ms/step - loss: 0.0064 - mae: 0.0633 - val_loss: 0.0058 - val_mae: 0.0614
# Epoch 53/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 47ms/step - loss: 0.0062 - mae: 0.0630 - val_loss: 0.0055 - val_mae: 0.0590
# Epoch 54/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 43ms/step - loss: 0.0061 - mae: 0.0623 - val_loss: 0.0051 - val_mae: 0.0565
# Epoch 55/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 41ms/step - loss: 0.0066 - mae: 0.0643 - val_loss: 0.0053 - val_mae: 0.0588
# Epoch 56/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 42ms/step - loss: 0.0059 - mae: 0.0606 - val_loss: 0.0051 - val_mae: 0.0567
# Epoch 57/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 41ms/step - loss: 0.0061 - mae: 0.0622 - val_loss: 0.0053 - val_mae: 0.0587
# Epoch 58/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 43ms/step - loss: 0.0062 - mae: 0.0621 - val_loss: 0.0059 - val_mae: 0.0622
# Epoch 59/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 42ms/step - loss: 0.0059 - mae: 0.0609 - val_loss: 0.0051 - val_mae: 0.0572
# Epoch 60/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 42ms/step - loss: 0.0062 - mae: 0.0627 - val_loss: 0.0052 - val_mae: 0.0577
# Epoch 61/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 42ms/step - loss: 0.0068 - mae: 0.0645 - val_loss: 0.0056 - val_mae: 0.0601
# Epoch 62/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 43ms/step - loss: 0.0060 - mae: 0.0618 - val_loss: 0.0050 - val_mae: 0.0563
# Epoch 63/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 40ms/step - loss: 0.0064 - mae: 0.0623 - val_loss: 0.0052 - val_mae: 0.0581
# Epoch 64/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 45ms/step - loss: 0.0059 - mae: 0.0613 - val_loss: 0.0050 - val_mae: 0.0566
# Epoch 65/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 42ms/step - loss: 0.0065 - mae: 0.0633 - val_loss: 0.0053 - val_mae: 0.0586
# Epoch 66/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 45ms/step - loss: 0.0064 - mae: 0.0637 - val_loss: 0.0051 - val_mae: 0.0574
# Epoch 67/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 44ms/step - loss: 0.0063 - mae: 0.0635 - val_loss: 0.0061 - val_mae: 0.0634
# Epoch 68/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 41ms/step - loss: 0.0064 - mae: 0.0636 - val_loss: 0.0051 - val_mae: 0.0568
# Epoch 69/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 47ms/step - loss: 0.0063 - mae: 0.0625 - val_loss: 0.0052 - val_mae: 0.0581
# Epoch 70/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 43ms/step - loss: 0.0062 - mae: 0.0635 - val_loss: 0.0052 - val_mae: 0.0579
# Epoch 71/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 55ms/step - loss: 0.0059 - mae: 0.0617 - val_loss: 0.0062 - val_mae: 0.0638
# Epoch 72/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 55ms/step - loss: 0.0059 - mae: 0.0610 - val_loss: 0.0050 - val_mae: 0.0563
# Epoch 73/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 49ms/step - loss: 0.0058 - mae: 0.0606 - val_loss: 0.0052 - val_mae: 0.0578
# Epoch 74/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 49ms/step - loss: 0.0062 - mae: 0.0628 - val_loss: 0.0059 - val_mae: 0.0619
# Epoch 75/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 51ms/step - loss: 0.0057 - mae: 0.0604 - val_loss: 0.0053 - val_mae: 0.0585
# Epoch 76/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 46ms/step - loss: 0.0055 - mae: 0.0585 - val_loss: 0.0052 - val_mae: 0.0579
# Epoch 77/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 42ms/step - loss: 0.0060 - mae: 0.0612 - val_loss: 0.0052 - val_mae: 0.0572
# Epoch 78/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 72ms/step - loss: 0.0059 - mae: 0.0613 - val_loss: 0.0050 - val_mae: 0.0563
# Epoch 79/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 58ms/step - loss: 0.0060 - mae: 0.0614 - val_loss: 0.0052 - val_mae: 0.0573
# Epoch 80/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 57ms/step - loss: 0.0058 - mae: 0.0608 - val_loss: 0.0051 - val_mae: 0.0571
# Epoch 81/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 55ms/step - loss: 0.0065 - mae: 0.0642 - val_loss: 0.0058 - val_mae: 0.0613
# Epoch 82/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 64ms/step - loss: 0.0059 - mae: 0.0612 - val_loss: 0.0050 - val_mae: 0.0561
# Epoch 83/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 63ms/step - loss: 0.0062 - mae: 0.0627 - val_loss: 0.0059 - val_mae: 0.0619
# Epoch 84/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 5s 63ms/step - loss: 0.0061 - mae: 0.0628 - val_loss: 0.0055 - val_mae: 0.0591
# Epoch 85/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 60ms/step - loss: 0.0056 - mae: 0.0600 - val_loss: 0.0050 - val_mae: 0.0566
# Epoch 86/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 59ms/step - loss: 0.0060 - mae: 0.0616 - val_loss: 0.0050 - val_mae: 0.0560
# Epoch 87/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 60ms/step - loss: 0.0058 - mae: 0.0601 - val_loss: 0.0055 - val_mae: 0.0599
# Epoch 88/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 56ms/step - loss: 0.0062 - mae: 0.0632 - val_loss: 0.0051 - val_mae: 0.0570
# Epoch 89/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 56ms/step - loss: 0.0065 - mae: 0.0646 - val_loss: 0.0065 - val_mae: 0.0654
# Epoch 90/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 56ms/step - loss: 0.0057 - mae: 0.0600 - val_loss: 0.0052 - val_mae: 0.0579
# Epoch 91/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 57ms/step - loss: 0.0060 - mae: 0.0612 - val_loss: 0.0050 - val_mae: 0.0560
# Epoch 92/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 62ms/step - loss: 0.0056 - mae: 0.0594 - val_loss: 0.0050 - val_mae: 0.0561
# Epoch 93/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 52ms/step - loss: 0.0058 - mae: 0.0613 - val_loss: 0.0060 - val_mae: 0.0624
# Epoch 94/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 57ms/step - loss: 0.0061 - mae: 0.0621 - val_loss: 0.0052 - val_mae: 0.0578
# Epoch 95/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 58ms/step - loss: 0.0059 - mae: 0.0607 - val_loss: 0.0054 - val_mae: 0.0584
# Epoch 96/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 67ms/step - loss: 0.0058 - mae: 0.0601 - val_loss: 0.0050 - val_mae: 0.0564
# Epoch 97/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 58ms/step - loss: 0.0062 - mae: 0.0623 - val_loss: 0.0050 - val_mae: 0.0567
# Epoch 98/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 52ms/step - loss: 0.0060 - mae: 0.0624 - val_loss: 0.0056 - val_mae: 0.0601
# Epoch 99/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 54ms/step - loss: 0.0057 - mae: 0.0600 - val_loss: 0.0052 - val_mae: 0.0579
# Epoch 100/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 54ms/step - loss: 0.0061 - mae: 0.0620 - val_loss: 0.0057 - val_mae: 0.0612
# Epoch 101/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 54ms/step - loss: 0.0061 - mae: 0.0629 - val_loss: 0.0054 - val_mae: 0.0593
# Epoch 102/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 51ms/step - loss: 0.0057 - mae: 0.0610 - val_loss: 0.0057 - val_mae: 0.0609
# Epoch 103/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 52ms/step - loss: 0.0058 - mae: 0.0610 - val_loss: 0.0055 - val_mae: 0.0598
# Epoch 104/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 49ms/step - loss: 0.0059 - mae: 0.0617 - val_loss: 0.0058 - val_mae: 0.0616
# Epoch 105/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 41ms/step - loss: 0.0061 - mae: 0.0620 - val_loss: 0.0060 - val_mae: 0.0628
# Epoch 106/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 42ms/step - loss: 0.0063 - mae: 0.0635 - val_loss: 0.0050 - val_mae: 0.0568

# %% [markdown]
# ## Evaluasi Model
# Evaluasi Model menggunakan metric evaluasi R-Squared dan MAPE
#
# R-Squared = seberapa baik model menjelaskan variasi dalam data
# MAPE = tingkat kesalahan prediksi dengan persentase
#
# R2 = 1 - (∑_(i=1)^n〖(yi-y ̂_i)〗^2 ) / (∑_(i=1)^n .〖(y_i-y ̅ )〗^2 ) <br>
# MAPE = 1/n ∑_(i=1)^n |(y_i-y ̂_i)/y_i |

# %%
# --- EVALUASI MODEL ---
y_pred = best_model.predict(X_test_seq)

# --- KEMBALIKAN SKALA PREDIKSI ---
y_pred_inv = scaler.inverse_transform(y_pred)
y_test_inv = scaler.inverse_transform(y_test_seq)

# --- HITUNG METRIK EVALUASI ---
r2 = r2_score(y_test_inv, y_pred_inv)
mape = np.mean(np.abs((y_test_inv - y_pred_inv) / y_test_inv)) * 100

print(f"R-Squared: {r2}")
print(f"MAPE: {mape}%")
# Out:
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step
# R-Squared: 0.7982884231599032
# MAPE: 0.043906970415257145%

# %%
# --- VISUALISASI HASIL PREDIKSI ---
plt.figure(figsize=(10, 4))
plt.plot(df.index[len(X_train) + timesteps:], y_test_inv, label='Data Aktual', color='blue')
plt.plot(df.index[len(X_train) + timesteps:], y_pred_inv, label='Prediksi Model', color='orange')

plt.xlabel('Tahun')
plt.ylabel(metrics_dict[feature])
plt.title(f'Perbandingan Data Aktual vs Prediksi ({feature_name})')
plt.grid(True)
plt.legend()
plt.show()

# %% [markdown]
# ## Prediksi Data di Masa Depan
#
# 1. Membuat fungsi prediksi yang melakukan prediksi data secara berulang menggunakan nilai prediksi sebelumnya
# 2. Mengembalikan prediksi ke skala aslinya dengan inverse transform (membalikkan normalisasi minmax)

# %%
def predict_until(target_date, model, data, scaler, timesteps, initial_date):
    # ----- Hitung jumlah hari dari tanggal terakhir data hingga target_date
    future_dates = pd.date_range(start=initial_date + timedelta(days=1), end=target_date)
    future_steps = len(future_dates)  # Hitung semua langkah prediksi

    # ----- Batasi prediksi maksimal 1 tahun ke depan (Opsional)
    max_forecast_days = 365
    max_date = initial_date + pd.Timedelta(days=max_forecast_days)
    
    if pd.Timestamp(target_date) > max_date:
        raise ValueError(f"Target date {target_date} melebihi batas prediksi: {max_date.date()}")
    
    # ----- Inisialisasi input data untuk prediksi awal
    current_input = data.reshape(1, timesteps, 1)  # Reshape input untuk LSTM
    
    # ----- Prediksi berulang untuk setiap hari di masa depan
    future_predictions = []
    for _ in range(future_steps):
        pred = model.predict(current_input)
        future_predictions.append(pred[0])
        
        # ----- Update input sequence dengan prediksi baru
        current_input = np.append(current_input[:, 1:, :], pred.reshape(1, 1, 1), axis=1)
    
    # ----- Kembalikan prediksi ke skala asli
    future_predictions_inv = scaler.inverse_transform(future_predictions)
    
    return future_dates, future_predictions_inv

# %% [markdown]
# 1. Definisi tanggal untuk diprediksi
# 2. Prediksi dengan model

# %%
# --- Prediksi hingga tanggal tertentu
target_date = "2024-9-20"
future_dates, future_preds = predict_until(target_date, best_model, X_test_seq[-1], scaler, timesteps, df.index[-1])

# ----- Menggabungkan hasil prediksi masa depan dengan data prediksi sebelumnya
combined_dates = np.concatenate([df.index[len(X_train) + timesteps:], future_dates])
combined_predictions = np.concatenate([y_pred_inv, future_preds])
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step

# %%
print(f"Prediksi {feature_name} pada {future_dates[-1]}: {future_preds[-1]}")
# Out:
# Prediksi Tekanan Permukaan pada 2024-09-20 00:00:00: [96.89602067]

# %% [markdown]
# #### Visualisasi Hasil Prediksi

# %%
# --- VISUALISASI HASIL PREDIKSI ---
plt.figure(figsize=(10, 4))
plt.plot(df.index[len(X_train) + timesteps:], y_test_inv, label='Data Aktual', color='blue')
plt.plot(df.index[len(X_train) + timesteps:], y_pred_inv, label='Prediksi Model', color='orange')
plt.plot(future_dates, future_preds, label='Prediksi Masa Depan', color='lime', linestyle='-')

# Anotasi prediksi pada target_date
plt.annotate(f'{future_preds[-1][0]:.2f} {metrics_dict[feature]}',
             xy=(future_dates[-1], future_preds[1][0]),
             xytext=(-10, 80),
             textcoords='offset points')

plt.xlabel('Tahun')
plt.ylabel(metrics_dict[feature])
plt.title(f'Prediksi {feature_name} Hingga {target_date}')
plt.grid(True)
plt.legend()
plt.show()

# %% [markdown]
# ## Save Model
# Save model dalam file berformat h5, pickle, dan Keras

# %%
import pickle

# Save Model
model_path = rf"C:\Users\Pujo Prayogo\Desktop\Kuliah\SKRIPSI\Kode\model/model_{feature_name}"

best_model.save(model_path+".h5")
best_model.save(model_path+".keras")
pickle.dump(best_model, open(f"best_{feature_name}_model.pkl", "wb"))
best_model.export(f"model_{feature_name}")

print(f'model h5 tersimpan di {model_path + ".h5"}')
print(f'model keras tersimpan di {model_path + ".keras"}')
print(f'model pickle tersimpan di {model_path + ".pkl"}')
print(f'model tersimpan di folder {model_path}')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# INFO:tensorflow:Assets written to: model_Tekanan Permukaan\assets
# INFO:tensorflow:Assets written to: model_Tekanan Permukaan\assets
# Saved artifact at 'model_Tekanan Permukaan'. The following endpoints are available:
#
# * Endpoint 'serve'
#   args_0 (POSITIONAL_ONLY): TensorSpec(shape=(None, 40, 1), dtype=tf.float32, name='keras_tensor')
# Output Type:
#   TensorSpec(shape=(None, 1), dtype=tf.float32, name=None)
# Captures:
#   2026581796112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2026581939472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2026582016768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2026582106704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2026582162240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2026582227248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2026582296352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2026582348544: TensorSpec(shape=(), dtype=tf.resource, name=None)
# model h5 tersimpan di C:\Users\Pujo Prayogo\Desktop\Kuliah\SKRIPSI\Kode\model/model_Tekanan Permukaan.h5
# model keras tersimpan di C:\Users\Pujo Prayogo\Desktop\Kuliah\SKRIPSI\Kode\model/model_Tekanan Permukaan.keras
# model pickle tersimpan di C:\Users\Pujo Prayogo\Desktop\Kuliah\SKRIPSI\Kode\model/model_Tekanan Permukaan.pkl
# model tersimpan di folder C:\Users\Pujo Prayogo\Desktop\Kuliah\SKRIPSI\Kode\model/model_Tekanan Permukaan
