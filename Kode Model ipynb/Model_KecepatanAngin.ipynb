# %% [markdown]
# # Weather Forecast LSTM
# ## Variabel: Kecepatan Angin (WS10M)
# #### Pujo Prayogo 140810200038 <br>
#
# Best Hyperparameter: <br>
#     LSTM Layers   : 1<br>
#     Unit          : 128<br>
#     Activation    : tanh <br>
#     Learning Rate : 0.01<br>
#     MAE Score     : 0.00029029781580902636<br>
#
# R2 Score      : 0.9964505341173552 <br>
# MAPE Score    : 0.7169951050127463%

# %%
import pandas as pd
import numpy as np
import keras_tuner
import requests
import json
import matplotlib.pyplot as plt
import keras_tuner as kt
import model
import shutil
import os

from datetime import timedelta, datetime
from statsmodels.tsa.stattools import acf

from scikeras.wrappers import KerasRegressor
from scikeras.wrappers import KerasRegressor
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import r2_score, mean_squared_error
from sklearn.model_selection import train_test_split, GridSearchCV

from tensorflow.keras.activations import relu, tanh, sigmoid
from tensorflow.keras.optimizers import Adam, RMSprop
from tensorflow.keras.models import Sequential, load_model
from tensorflow.keras.layers import LSTM, Dense, Flatten, Input, Dropout
from tensorflow.keras.callbacks import EarlyStopping

# %% [markdown]
# # Import Data
#
# 1. Define fitur variabel, tanggal, dan koordinat lokasi
# 2. Import data cuaca melalui API POWER NASA
# 3. Konversi data JSON menjadi DataFrame

# %%
# ----- Parameter 
feature = "WS10M"  # Variabel: GWETROOT, WS10M, PS, PRECTOTCORR, RH2M, T2M

# ----- Data dan metric/satuannya
renamed_dict = {
    "GWETROOT": "Kelembaban Tanah",
    "WS10M": "Kecepatan Angin",
    "PS": "Tekanan Permukaan",
    "PRECTOTCORR": "Presipitasi",
    "RH2M": "Kelembaban Udara",
    "T2M": "Temperatur"
}

feature_name = renamed_dict[feature]  # Rename variabel fitur

metrics_dict = {
    "GWETROOT": "", #Hanya 0-1
    "WS10M": "m/s",
    "PS": "kPa",
    "PRECTOTCORR": "mm/day",
    "RH2M": "C",
    "T2M": "g/kg"
}

# ----- Tanggal dan Koordinat lokasi data pada POWER NASA
start_date = "20190101"
end_date = "20231231"
lat = "-6.3968"
long = "106.8458"

# ----- Download Data melalui API POWER NASA
request_url = (
    f"https://power.larc.nasa.gov/api/temporal/daily/point?"
    f"start={start_date}&end={end_date}&latitude={lat}&longitude={long}&community=ag&"
    f"parameters={feature}&format=json&user=pujo&header=true&time-standard=lst"
)
response = requests.get(url=request_url, verify=True, timeout=30.00)
content = json.loads(response.content.decode('utf-8'))

# ----- Konversi data ke DataFrame
df = pd.DataFrame.from_dict(content['properties']['parameter'])
df.index = pd.to_datetime(df.index, format='%Y%m%d')

# ----- Rename Kolom
df.rename(columns={feature: feature_name}, inplace=True)

# %% [markdown]
# #### Pengecekan data null/invalid (-999)

# %%
# ----- Cek Data
print(df, '\n\n')
print(df.info(), '\n')

# ----- Cek Data Invalid (Bernilai -999)
invalid_data = (df == -999).sum().sum()
print("TIDAK ADA DATA INVALID" if invalid_data == 0 else f"TERDAPAT DATA INVALID SEBANYAK {invalid_data} DATA")
# Out:
#             Kecepatan Angin
# 2019-01-01             4.29
# 2019-01-02             4.43
# 2019-01-03             4.44
# 2019-01-04             3.23
# 2019-01-05             1.81
# ...                     ...
# 2023-12-27             1.09
# 2023-12-28             1.66
# 2023-12-29             1.52
# 2023-12-30             1.15
# 2023-12-31             1.30
#
# [1826 rows x 1 columns]
#
#
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1826 entries, 2019-01-01 to 2023-12-31
# Data columns (total 1 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Kecepatan Angin  1826 non-null   float64
# dtypes: float64(1)
# memory usage: 28.5 KB
# None
#
# TIDAK ADA DATA INVALID

# %% [markdown]
# #### Visualisasi data dalam grafik
# Menampilkan grafik sebaran data

# %%
# ----- Visualisasi Data
plt.figure(figsize=(10, 4))
plt.plot(df.index, df[feature_name], label=feature_name)
plt.xlabel('Tahun')
plt.ylabel(metrics_dict[feature])  # Y-axis dinamis sesuai parameter
plt.title(f'Sebaran Data {feature_name}')
plt.grid(True)
plt.legend()
plt.show()

# %% [markdown]
# ## Autokorelasi
# Menampilkan grafik autokorelasi dengan acf untuk menentukan timesteps.
# Timesteps menurun secara konsisten sehingga diambil nilai acak sebagai timesteps, yaitu 30

# %%
# ----- Autokorelasi untuk menentukan TImesteps
def determine_timesteps(df, max_lag=60):
    lag_acf = acf(df[feature_name], nlags=max_lag)

    # Visualisasi autokorelasi
    plt.figure(figsize=(10, 4))
    plt.stem(range(len(lag_acf)), lag_acf)
    plt.title(f'Autocorrelation untuk {feature_name}')
    plt.xlabel('Lag (Hari)')
    plt.ylabel('Autocorrelation')
    plt.show()

    return lag_acf

autocorrelation = determine_timesteps(df)

# %% [markdown]
# ## Scaling data dengan MinMax
#
# 1. Scaling dengan MinMax
# 2. Pembagian data menjadi data Training (80%) dan data Testing (20%) tanpa mengubah urutan data
# 3. Visualisasi pembagian data training dan testing
#
# x' = x - min(x) / max(x) - min(x) <br>
# x = Data original

# %%
# ----- Scaling data dengan MinMax
scaler = MinMaxScaler()
scaled_data = scaler.fit_transform(df[[feature_name]])

# Train-Test Split (8:2)
X_train, X_test, y_train, y_test = train_test_split(
    scaled_data, scaled_data, test_size=0.2, shuffle=False
)

# ----- Visualisasi Train-Test Split
plt.figure(figsize=(10, 4))
plt.plot(df.index[:len(X_train)], X_train, label='Train')
plt.plot(df.index[len(X_train):], X_test, label='Test', color='orange')
plt.xlabel('Tahun')
plt.ylabel(metrics_dict[feature])
plt.title(f'Pembagian Data Train dan Test ({feature_name})')
plt.grid(True)
plt.legend()
plt.show()

# %% [markdown]
# ## Sequencing
#
# 1. Mendefinisikan timesteps
# 2. Membuat Fungsi untuk mempersiapkan data input yang sesuai format model LSTM.
#    Data diubah menjadi sekuens sepanjang timesteps (20)
# 4. Reshaping data menjadi format 3D untuk input LSTM [jumlah_sekuens, timesteps, jumlah_fitur]

# %%
timesteps = 20

# ----- Fungsi Membuat Sequence 
def create_sequences(X, time_steps):
    X_seq, y_seq = [], []
    for i in range(len(X) - time_steps):
        X_seq.append(X[i:i + time_steps])
        y_seq.append(X[i + time_steps])
    return np.array(X_seq), np.array(y_seq)

X_train_seq, y_train_seq = create_sequences(X_train, timesteps)
X_test_seq, y_test_seq = create_sequences(X_test, timesteps)

# ----- Reshape untuk LSTM
X_train_seq = X_train_seq.reshape((X_train_seq.shape[0], X_train_seq.shape[1], 1))
X_test_seq = X_test_seq.reshape((X_test_seq.shape[0], X_test_seq.shape[1], 1))

# %% [markdown]
# #### Membuat Directory untuk menyimpan hasil Tuning (Overwrite jika sudah ada)

# %%
#Hapus Directory Tuning (hanya untuk Tuning ulang)
#tuning_dir = f'lstm_tuning_{feature_name}_dir'

#if os.path.exists(tuning_dir):
#    shutil.rmtree(tuning_dir)
#    print(f"Deleted previous tuning directory: {tuning_dir}")
#else:
#    print(f"Tuning directory not found: {tuning_dir}")

# %% [markdown]
# # Hyperparameter Tuning dengan KerasTuner
# 1. Membuat fungsi model LSTM:
#    - Tuning jumlah layer LSTM (1 atau 2).
#     - Tuning jumlah unit per layer (32, 64, atau 128).
#     - Tuning fungsi aktivasi (relu, tanh, atau sigmoid).
#     - Tuning optimizer (adam atau rmsprop) dan learning rate (0.01 atau 0.001).
# 2. Menambah Dropout (0.2) untuk mencegah overfitting
# 3. Inisiasi Tuner dengan trials sebanyak 72 kombinasi dan 1 eksekusi/trial
# 4. Mengaplikasikan callback EarlyStopping untuk menghentikan pelatihan jika tidak terdapat perbaikan selama 15 epochs berturut-turut

# %%
# ----- Fungsi membangun Model LSTM dengan Keras Tuner
def build_model(hp):
    model = Sequential()

    # ------ Jumlah Layers, jumlah unit, fungsi aktivasi
    for i in range(hp.Choice('layers', [1, 2])):  # Tuning layer LSTM (2)
        model.add(LSTM(
            units=hp.Choice('filters', [32, 64, 128]),  # Tuning jumlah unit pada layer LSTM (3) 
            activation=hp.Choice('activation', ['relu', 'tanh', 'sigmoid']),  # Tuning fungsi aktivasi (3)
            return_sequences=True if i < hp.Choice('layers', [1, 2]) - 1 else False  
        ))
        model.add(Dropout(0.2)) # Dropout
    model.add(Dense(1))
    
    # ----- Optimizer dan Learning Rate
    optimizer_choice = hp.Choice('optimizer', ['adam', 'rmsprop']) # Tuning Optimizer (2)
    learning_rate = hp.Choice('learning_rate', [0.01, 0.001]) # Tuning learning Rate (2)
     
    if optimizer_choice == 'adam':
        optimizer = Adam(learning_rate=learning_rate)
    else:
        optimizer = RMSprop(learning_rate=learning_rate)
    
    # ----- Compile Model
    model.compile(optimizer=optimizer, loss='mean_squared_error', metrics=['mae'])
    
    return model

# --- Callback Early Stopping dengan Patience 15
early_stopping = EarlyStopping(
    monitor='val_loss',
    patience=15,
    restore_best_weights=True
)

# ----- Inisiasi Tuner 
tuner = kt.GridSearch(
    build_model,
    objective='val_loss',
    max_trials=72,  # Jumlah Kombinasi Hyperparameter
    executions_per_trial=1,  # 2x training per kombinasi hyperparameter
    directory=f'lstm_tuning_{feature_name}_dir',
    project_name=f'lstm_{feature_name}_tuning'
)
# Out:
# Reloading Tuner from lstm_tuning_Kecepatan Angin_dir\lstm_Kecepatan Angin_tuning\tuner0.json

# %% [markdown]
# #### Tuning dengan epochs 200 dan patience Earlystopping 15

# %%
# ----- Hyperparameter Tuning
tuner.search(
    X_train_seq, y_train_seq,
    epochs=200,
    batch_size=32,
    validation_data=(X_test_seq, y_test_seq),
    callbacks=[early_stopping]
)

# %% [markdown]
# #### Output Hyperparameter Tuning (Konfigurasi terbaik & hasil seluruh Trials)

# %%
# ----- Output Best Hyperparameter
best_hps = tuner.get_best_hyperparameters(num_trials=1)[0]
tuner_results = tuner.oracle.get_best_trials(num_trials=72)  
results = []

# Memasukkan Hasil Tuning ke DataFrame
for trial in tuner_results:
    values = trial.hyperparameters.values
    values['score'] = trial.score  # Nilai skor (mae)
    values['layers'] = trial.hyperparameters.get('layers')  # Menambahkan jumlah layer
    results.append(values)

df_results = pd.DataFrame(results)

# Tampilkan semua baris
pd.set_option('display.max_rows', None)  # Tampilkan semua baris
pd.set_option('display.max_columns', None)  # Tampilkan semua kolom

# Print Hyperparameter Terbaik
print("\n--- Setting Hyperparameter Terbaik ---")
print(f"Layer(s): {best_hps.get('layers')}")  # Menambahkan jumlah layer
print(f"Filters (units LSTM): {best_hps.get('filters')}")
print(f"Activation: {best_hps.get('activation')}")
print(f"Optimizer: {best_hps.get('optimizer')}")
print(f"Learning Rate: {best_hps.get('learning_rate')}")
print(f"Score (MAE): {best_hps.get('score')}\n\n")

# Print seluruh hasil hyperparameter tuning
print('Hasil Hyperparameter Tuning')
print(df_results)
# Out:
# --- Setting Hyperparameter Terbaik ---
# Layer(s): 2
# Filters (units LSTM): 64
# Activation: tanh
# Optimizer: rmsprop
# Learning Rate: 0.01
# Score (MAE): 0.007130006793886423
#
#
# Hasil Hyperparameter Tuning
#     layers  filters activation optimizer  learning_rate     score
# 0        2       64       tanh   rmsprop          0.010  0.007130
# 1        1       32       tanh   rmsprop          0.010  0.007172
# 2        2       64       tanh      adam          0.010  0.007250
# 3        1       64       tanh   rmsprop          0.001  0.007280
# 4        1      128    sigmoid      adam          0.010  0.007286
# 5        2      128       tanh      adam          0.001  0.007304
# 6        1       64       tanh   rmsprop          0.010  0.007305
# 7        2       64       tanh   rmsprop          0.001  0.007308
# 8        1      128       tanh   rmsprop          0.010  0.007320
# 9        1      128       tanh      adam          0.010  0.007337
# 10       1       64       tanh      adam          0.010  0.007341
# 11       1      128       tanh   rmsprop          0.001  0.007347
# 12       1      128       tanh      adam          0.001  0.007349
# 13       1       64       tanh      adam          0.001  0.007356
# 14       2       32       tanh   rmsprop          0.001  0.007357
# 15       2      128       tanh   rmsprop          0.001  0.007362
# 16       1       32       tanh      adam          0.010  0.007369
# 17       1       32       tanh   rmsprop          0.001  0.007388
# 18       2      128       tanh      adam          0.010  0.007402
# 19       2      128       tanh   rmsprop          0.010  0.007411
# 20       1      128       relu   rmsprop          0.001  0.007420
# 21       2       32       tanh      adam          0.010  0.007425
# 22       1       32       tanh      adam          0.001  0.007471
# 23       2       64       tanh      adam          0.001  0.007488
# 24       1       64       relu      adam          0.010  0.007540
# 25       2      128       relu      adam          0.001  0.007545
# 26       1       64       relu      adam          0.001  0.007546
# 27       2       32       tanh      adam          0.001  0.007560
# 28       1      128    sigmoid      adam          0.001  0.007561
# 29       1       64       relu   rmsprop          0.001  0.007569
# 30       1       64       relu   rmsprop          0.010  0.007606
# 31       1      128       relu      adam          0.001  0.007613
# 32       2      128    sigmoid      adam          0.010  0.007663
# 33       1       32    sigmoid   rmsprop          0.010  0.007666
# 34       1      128       relu      adam          0.010  0.007674
# 35       2       64       relu      adam          0.001  0.007693
# 36       1       64    sigmoid      adam          0.010  0.007722
# 37       2      128       relu      adam          0.010  0.007727
# 38       1      128       relu   rmsprop          0.010  0.007773
# 39       2      128       relu   rmsprop          0.001  0.007776
# 40       1       64    sigmoid   rmsprop          0.001  0.007839
# 41       1       32       relu   rmsprop          0.010  0.007842
# 42       2       32    sigmoid      adam          0.010  0.007857
# 43       1       32       relu      adam          0.001  0.007863
# 44       2       64    sigmoid      adam          0.010  0.007886
# 45       2       64       relu   rmsprop          0.001  0.007892
# 46       2       64       relu   rmsprop          0.010  0.007912
# 47       2       32       tanh   rmsprop          0.010  0.007922
# 48       1       64    sigmoid   rmsprop          0.010  0.007949
# 49       2       32       relu   rmsprop          0.010  0.007959
# 50       1       32       relu      adam          0.010  0.007959
# 51       1       32    sigmoid      adam          0.010  0.008011
# 52       1       32    sigmoid      adam          0.001  0.008018
# 53       2       64    sigmoid   rmsprop          0.010  0.008020
# 54       1      128    sigmoid   rmsprop          0.001  0.008050
# 55       1       64    sigmoid      adam          0.001  0.008077
# 56       1       32       relu   rmsprop          0.001  0.008079
# 57       1       32    sigmoid   rmsprop          0.001  0.008108
# 58       2       32       relu      adam          0.010  0.008120
# 59       2       32       relu   rmsprop          0.001  0.008139
# 60       2      128       relu   rmsprop          0.010  0.008244
# 61       2       32       relu      adam          0.001  0.008270
# 62       1      128    sigmoid   rmsprop          0.010  0.008390
# 63       2       32    sigmoid   rmsprop          0.010  0.008397
# 64       2       64       relu      adam          0.010  0.008518
# 65       2      128    sigmoid   rmsprop          0.010  0.008702
# 66       2       64    sigmoid      adam          0.001  0.020757
# 67       2       64    sigmoid   rmsprop          0.001  0.020836
# 68       2      128    sigmoid      adam          0.001  0.020842
# 69       2       32    sigmoid   rmsprop          0.001  0.020903
# 70       2      128    sigmoid   rmsprop          0.001  0.020944
# 71       2       32    sigmoid      adam          0.001  0.021102

# %% [markdown]
# ### Melatih ulang Model dengan Hyperparameter terbaik

# %%
# ----- Train Model dengan Hyperparameter terbaik
best_model = tuner.hypermodel.build(best_hps)

# --- LATIH ULANG MODEL DENGAN DATA TRAINING ---
history = best_model.fit(
    X_train_seq, y_train_seq,
    epochs=200,
    batch_size=32, 
    validation_data=(X_test_seq, y_test_seq),
    callbacks=[early_stopping]
)
# Out:
# Epoch 1/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 8s 55ms/step - loss: 0.3988 - mae: 0.3260 - val_loss: 0.0242 - val_mae: 0.1360
# Epoch 2/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0230 - mae: 0.1204 - val_loss: 0.0138 - val_mae: 0.0964
# Epoch 3/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0174 - mae: 0.1032 - val_loss: 0.0118 - val_mae: 0.0890
# Epoch 4/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0188 - mae: 0.1059 - val_loss: 0.0099 - val_mae: 0.0808
# Epoch 5/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.0160 - mae: 0.1000 - val_loss: 0.0129 - val_mae: 0.0849
# Epoch 6/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.0156 - mae: 0.0977 - val_loss: 0.0104 - val_mae: 0.0854
# Epoch 7/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0132 - mae: 0.0921 - val_loss: 0.0099 - val_mae: 0.0770
# Epoch 8/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 0.0134 - mae: 0.0914 - val_loss: 0.0098 - val_mae: 0.0783
# Epoch 9/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0136 - mae: 0.0893 - val_loss: 0.0089 - val_mae: 0.0738
# Epoch 10/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.0133 - mae: 0.0918 - val_loss: 0.0078 - val_mae: 0.0725
# Epoch 11/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0127 - mae: 0.0873 - val_loss: 0.0079 - val_mae: 0.0732
# Epoch 12/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0133 - mae: 0.0895 - val_loss: 0.0093 - val_mae: 0.0760
# Epoch 13/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0126 - mae: 0.0874 - val_loss: 0.0081 - val_mae: 0.0734
# Epoch 14/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.0122 - mae: 0.0860 - val_loss: 0.0119 - val_mae: 0.0860
# Epoch 15/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.0130 - mae: 0.0904 - val_loss: 0.0107 - val_mae: 0.0859
# Epoch 16/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0130 - mae: 0.0893 - val_loss: 0.0082 - val_mae: 0.0746
# Epoch 17/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.0139 - mae: 0.0916 - val_loss: 0.0084 - val_mae: 0.0760
# Epoch 18/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0129 - mae: 0.0886 - val_loss: 0.0097 - val_mae: 0.0758
# Epoch 19/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0122 - mae: 0.0855 - val_loss: 0.0077 - val_mae: 0.0721
# Epoch 20/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 0.0129 - mae: 0.0888 - val_loss: 0.0082 - val_mae: 0.0743
# Epoch 21/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.0128 - mae: 0.0883 - val_loss: 0.0093 - val_mae: 0.0803
# Epoch 22/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 0.0124 - mae: 0.0866 - val_loss: 0.0087 - val_mae: 0.0776
# Epoch 23/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - loss: 0.0130 - mae: 0.0897 - val_loss: 0.0076 - val_mae: 0.0718
# Epoch 24/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - loss: 0.0121 - mae: 0.0853 - val_loss: 0.0082 - val_mae: 0.0751
# Epoch 25/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 0.0128 - mae: 0.0891 - val_loss: 0.0085 - val_mae: 0.0724
# Epoch 26/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.0121 - mae: 0.0864 - val_loss: 0.0125 - val_mae: 0.0928
# Epoch 27/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step - loss: 0.0126 - mae: 0.0875 - val_loss: 0.0079 - val_mae: 0.0736
# Epoch 28/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - loss: 0.0120 - mae: 0.0861 - val_loss: 0.0076 - val_mae: 0.0718
# Epoch 29/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step - loss: 0.0126 - mae: 0.0887 - val_loss: 0.0074 - val_mae: 0.0689
# Epoch 30/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 43ms/step - loss: 0.0117 - mae: 0.0848 - val_loss: 0.0080 - val_mae: 0.0740
# Epoch 31/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 0.0118 - mae: 0.0849 - val_loss: 0.0082 - val_mae: 0.0751
# Epoch 32/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 0.0131 - mae: 0.0899 - val_loss: 0.0093 - val_mae: 0.0772
# Epoch 33/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 0.0126 - mae: 0.0890 - val_loss: 0.0076 - val_mae: 0.0706
# Epoch 34/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0117 - mae: 0.0854 - val_loss: 0.0112 - val_mae: 0.0876
# Epoch 35/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 0.0118 - mae: 0.0862 - val_loss: 0.0083 - val_mae: 0.0736
# Epoch 36/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.0122 - mae: 0.0864 - val_loss: 0.0083 - val_mae: 0.0749
# Epoch 37/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - loss: 0.0119 - mae: 0.0856 - val_loss: 0.0074 - val_mae: 0.0701
# Epoch 38/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - loss: 0.0119 - mae: 0.0849 - val_loss: 0.0092 - val_mae: 0.0746
# Epoch 39/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 0.0127 - mae: 0.0887 - val_loss: 0.0097 - val_mae: 0.0757
# Epoch 40/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0126 - mae: 0.0875 - val_loss: 0.0097 - val_mae: 0.0825
# Epoch 41/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0124 - mae: 0.0864 - val_loss: 0.0085 - val_mae: 0.0769
# Epoch 42/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 0.0120 - mae: 0.0855 - val_loss: 0.0077 - val_mae: 0.0722
# Epoch 43/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.0112 - mae: 0.0832 - val_loss: 0.0080 - val_mae: 0.0731
# Epoch 44/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 0.0111 - mae: 0.0838 - val_loss: 0.0082 - val_mae: 0.0739
# Epoch 45/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.0119 - mae: 0.0858 - val_loss: 0.0078 - val_mae: 0.0703
# Epoch 46/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 0.0112 - mae: 0.0832 - val_loss: 0.0075 - val_mae: 0.0689
# Epoch 47/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.0133 - mae: 0.0899 - val_loss: 0.0080 - val_mae: 0.0722
# Epoch 48/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.0113 - mae: 0.0844 - val_loss: 0.0088 - val_mae: 0.0781
# Epoch 49/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.0120 - mae: 0.0865 - val_loss: 0.0081 - val_mae: 0.0745
# Epoch 50/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0123 - mae: 0.0880 - val_loss: 0.0081 - val_mae: 0.0729
# Epoch 51/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0120 - mae: 0.0856 - val_loss: 0.0077 - val_mae: 0.0699
# Epoch 52/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.0124 - mae: 0.0883 - val_loss: 0.0085 - val_mae: 0.0771

# %% [markdown]
# ## Evaluasi Model
# Evaluasi Model menggunakan metric evaluasi R-Squared dan MAPE
#
# R-Squared = seberapa baik model menjelaskan variasi dalam data
# MAPE = tingkat kesalahan prediksi dengan persentase
#
# R2 = 1 - (∑_(i=1)^n〖(yi-y ̂_i)〗^2 ) / (∑_(i=1)^n .〖(y_i-y ̅ )〗^2 ) <br>
# MAPE = 1/n ∑_(i=1)^n |(y_i-y ̂_i)/y_i |

# %%
# --- EVALUASI MODEL ---
y_pred = best_model.predict(X_test_seq)

# --- KEMBALIKAN SKALA PREDIKSI ---
y_pred_inv = scaler.inverse_transform(y_pred)
y_test_inv = scaler.inverse_transform(y_test_seq)

# --- HITUNG METRIK EVALUASI ---
r2 = r2_score(y_test_inv, y_pred_inv)
mape = np.mean(np.abs((y_test_inv - y_pred_inv) / y_test_inv)) * 100

print(f"R-Squared: {r2}")
print(f"MAPE: {mape}%")
# Out:
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 74ms/step
# R-Squared: 0.668535145652768
# MAPE: 19.16947039306854%

# %%
# --- VISUALISASI HASIL PREDIKSI ---
plt.figure(figsize=(10, 4))
plt.plot(df.index[len(X_train) + timesteps:], y_test_inv, label='Data Aktual', color='blue')
plt.plot(df.index[len(X_train) + timesteps:], y_pred_inv, label='Prediksi Model', color='orange')

plt.xlabel('Tahun')
plt.ylabel(metrics_dict[feature])
plt.title(f'Perbandingan Data Aktual vs Prediksi ({feature_name})')
plt.grid(True)
plt.legend()
plt.show()

# %% [markdown]
# ## Prediksi Data di Masa Depan
#
# 1. Membuat fungsi prediksi yang melakukan prediksi data secara berulang menggunakan nilai prediksi sebelumnya
# 2. Mengembalikan prediksi ke skala aslinya dengan inverse transform (membalikkan normalisasi minmax)

# %%
def predict_until(target_date, model, data, scaler, timesteps, initial_date):
    # ----- Hitung jumlah hari dari tanggal terakhir data hingga target_date
    future_dates = pd.date_range(start=initial_date + timedelta(days=1), end=target_date)
    future_steps = len(future_dates)  # Hitung semua langkah prediksi

    # ----- Batasi prediksi maksimal 1 tahun ke depan (Opsional)
    max_forecast_days = 365
    max_date = initial_date + pd.Timedelta(days=max_forecast_days)
    
    if pd.Timestamp(target_date) > max_date:
        raise ValueError(f"Target date {target_date} melebihi batas prediksi: {max_date.date()}")
    
    # ----- Inisialisasi input data untuk prediksi awal
    current_input = data.reshape(1, timesteps, 1)  # Reshape input untuk LSTM
    
    # ----- Prediksi berulang untuk setiap hari di masa depan
    future_predictions = []
    for _ in range(future_steps):
        pred = model.predict(current_input)
        future_predictions.append(pred[0])
        
        # ----- Update input sequence dengan prediksi baru
        current_input = np.append(current_input[:, 1:, :], pred.reshape(1, 1, 1), axis=1)
    
    # ----- Kembalikan prediksi ke skala asli
    future_predictions_inv = scaler.inverse_transform(future_predictions)
    
    return future_dates, future_predictions_inv

# %% [markdown]
# 1. Definisi tanggal untuk diprediksi
# 2. Prediksi dengan model

# %%
# --- Prediksi hingga tanggal tertentu
target_date = "2024-9-20"
future_dates, future_preds = predict_until(target_date, best_model, X_test_seq[-1], scaler, timesteps, df.index[-1])

# ----- Menggabungkan hasil prediksi masa depan dengan data prediksi sebelumnya
combined_dates = np.concatenate([df.index[len(X_train) + timesteps:], future_dates])
combined_predictions = np.concatenate([y_pred_inv, future_preds])
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 168ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 158ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step

# %%
print(f"Prediksi {feature_name} pada {future_dates[-1]}: {future_preds[-1]}")
# Out:
# Prediksi Kecepatan Angin pada 2024-09-20 00:00:00: [1.84659911]

# %% [markdown]
# #### Visualisasi Hasil Prediksi

# %%
# --- VISUALISASI HASIL PREDIKSI ---
plt.figure(figsize=(10, 4))
plt.plot(df.index[len(X_train) + timesteps:], y_test_inv, label='Data Aktual', color='blue')
plt.plot(df.index[len(X_train) + timesteps:], y_pred_inv, label='Prediksi Model', color='orange')
plt.plot(future_dates, future_preds, label='Prediksi Masa Depan', color='lime', linestyle='-')

# Anotasi prediksi pada target_date
plt.annotate(f'{future_preds[-1][0]:.2f} {metrics_dict[feature]}',
             xy=(future_dates[-1], future_preds[1][0]),
             xytext=(-10, 80),
             textcoords='offset points')

plt.xlabel('Tahun')
plt.ylabel(metrics_dict[feature])
plt.title(f'Prediksi {feature_name} Hingga {target_date}')
plt.grid(True)
plt.legend()
plt.show()

# %% [markdown]
# ## Save Model
# Save model dalam file berformat h5, pickle, dan Keras

# %%
import pickle

# Save Model
model_path = rf"C:\Users\Pujo Prayogo\Desktop\Kuliah\SKRIPSI\Kode\model/model_{feature_name}"

best_model.save(model_path+".h5")
best_model.save(model_path+".keras")
pickle.dump(best_model, open(f"best_{feature_name}_model.pkl", "wb"))
best_model.export(f"model_{feature_name}")

print(f'model h5 tersimpan di {model_path + ".h5"}')
print(f'model keras tersimpan di {model_path + ".keras"}')
print(f'model pickle tersimpan di {model_path + ".pkl"}')
print(f'model tersimpan di folder {model_path}')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# INFO:tensorflow:Assets written to: model_Kecepatan Angin\assets
# INFO:tensorflow:Assets written to: model_Kecepatan Angin\assets
# Saved artifact at 'model_Kecepatan Angin'. The following endpoints are available:
#
# * Endpoint 'serve'
#   args_0 (POSITIONAL_ONLY): TensorSpec(shape=(None, 20, 1), dtype=tf.float32, name='keras_tensor')
# Output Type:
#   TensorSpec(shape=(None, 1), dtype=tf.float32, name=None)
# Captures:
#   2161027302848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2161044452624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2161044513536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2161044599376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2161044654912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2161044724016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2161044784928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2161044845312: TensorSpec(shape=(), dtype=tf.resource, name=None)
# model h5 tersimpan di C:\Users\Pujo Prayogo\Desktop\Kuliah\SKRIPSI\Kode\model/model_Kecepatan Angin.h5
# model keras tersimpan di C:\Users\Pujo Prayogo\Desktop\Kuliah\SKRIPSI\Kode\model/model_Kecepatan Angin.keras
# model pickle tersimpan di C:\Users\Pujo Prayogo\Desktop\Kuliah\SKRIPSI\Kode\model/model_Kecepatan Angin.pkl
# model tersimpan di folder C:\Users\Pujo Prayogo\Desktop\Kuliah\SKRIPSI\Kode\model/model_Kecepatan Angin
